# %%
def my_function():
    var = 10 
    print(var)
my_function()
print(var)
# Out:
# 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       3     print(var)
#       4 my_function()
# ----> 5 print(var)
#
# NameError: name 'var' is not defined

# %%
var = 20
def my_function():
    var = 10 
    print(var)
my_function()
print(var)
# Out:
# 10
# 20

# %%
a = 10
def display():
    a = 30 
    def show():
        var = 20
        print(var)
    show()
    print(a)
display()
print(a)
# Out:
# 20
# 30
# 10

# %%
a = 10
def display():
    global a
    a = a+1
    print(a)
display()
# Out:
# 11

# %%
a = 10 
def display():
    a = 20
    def show():
        global a 
        print(f"values 'a' before modifiying in show() function{ a}")
        a = 30 
        print(f"values 'a' after modifiying in show() function {a}")
    show()
print(f"values 'a' before modifiying in display() function{a}")    
display()
print(f"values 'a' after modifiying in display() function{ a}")
# Out:
# values 'a' before modifiying in display() function10
# values 'a' before modifiying in show() function10
# values 'a' after modifiying in show() function 30
# values 'a' after modifiying in display() function30

# %%
outside_mango_tree = "outside the compound wall"
def house():
    inside_Mango_tree = "inside the compound wall"
    def make_pickel():
        return outside_mango_tree
    return make_pickel
house = house()
print(house())
# Out:
# outside the compound wall

# %%
Balance = 1000

def check_balance():
    print(f"Your current balance is : ${Balance}")

def deposit():
    global Balance
    amount = int(input("Enter the amount to deposit: "))
    Balance +=amount
    print(f"{amount} deposited successfully . New Balance is: ${Balance}")
def withdrawn():
    global Balance
    amount = int(input("Enter the amount to withdrawn: "))
    if amount <= Balance:
        Balance -= amount
        print(f"{amount} withdrawn successfully . New Balance is: ${Balance}")
    else:
        print("Insufficient funds!")



check_balance()
deposit()
withdrawn()
check_balance()
# Out:
# Your current balance is : $1000
# 2000 deposited successfully . New Balance is: $3000
# Insufficient funds!
# Your current balance is : $3000
