# %%
for i in range(5):
    print(i * i)
# Out:
# 0
# 1
# 4
# 9
# 16

# %%
# Add two numbers
a = 5
b = 7
print (a + b)
# Out:
# 12

# %%
# Substraction two numbers
a = int(input("Enter number a"))
b = int(input("Enter number b"))
add = a + b
sub = a - b
mul = a * b
div = a / b
print("Arithmetic Opeations")
print("-------------------------")
print("Addition of",a ,"&", b," = ",add)
print("Substraction of",a ,"&", b," = ",sub)
print("Multiplication of",a ,"&", b," = ",mul)
print("Division of",a ,"&", b," = ",div)
# Out:
# Arithmetic Opeations
# -------------------------
# Addition of 12 & 5  =  17
# Substaction of 12 & 5  =  7
# Multiplication of 12 & 5  =  60
# Division of 12 & 5  =  2.4
